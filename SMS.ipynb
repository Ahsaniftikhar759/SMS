# %%
import getpass
class SMS():
    def __init__(self,school_name,school_address):
        self.school_name=school_name
        self.school_address=school_address
        print("|-------------------------------------|")
        print("WELCOME TO SCHOOL MANAGEMENT SYSTEM")
        print("|-------------------------------------|")
        
    def info(self):
        SM.registration()
        SM.principal()
        SM.teacher()
        SM.student()
        SM.classes()
        
        SM.course()
        SM.teacher_info()
        SM.fee_submition()
    def principal(self):
        print('--------------------')
        print("Teacher Information")
        print('--------------------')
        print("|-------------------------------------------------------------------------|")
        print("\t\t- The Owner of the school is Ahsan Iftikhar\n")
        print("\t\t- Bscs from Islamabad University")
        print("|-------------------------------------------------------------------------|")
    def teacher(self):
        print("===============")
        print("List of Teacher")
        print("===============")
        drs={
                'Qammar' : ' : english',
                'Hammed' : ' : urdu',
                'Kamraan': ' : math',
                'Faizan' : ' : biology',
                'Ajmal'  : ' : physics',
                'Rafeeq' : ' : pak studies',
                'Kashif' : ' : chemistry',
                'Nasir ' : ' : computer'
                }
        for i,j in drs.items():
                print(f"{i} is the teacher of {j} ")
# -----------------------------------------------------------------------------------
    def student(self):
        print('--------------------')
        print("Student Information")
        print('--------------------')
        print("- There are 1200 students in our school ")
        
        print('\n')
# ----------------------------------------------------------------------------------------
    def classes(self):
        print('--------------------')
        print("Classes Information")
        print('--------------------')
        print("There are 12 classes in our school  all the classes are neat and clean")
       
        print('\n')
#-------------------------------------------------------------------------------------------
    def registration(self):
        print('---------------------------')
        print("Registerd You On Our School")
        print('---------------------------')
        print("Enter your details")
        f_name=input("Enter your first name : ")
        l_name=input("Enter your last name : ")
        password=getpass.getpass("Set Your Password : ")
        c_password=getpass.getpass("Confirm password : ")
        if password==c_password:
            Gender=input("Enter gender name : ")
            print(Gender)
            print("Date of Birth : ")
            date=int(input("Enter date : "))
            month=int(input("Enter Month : "))
            year=int(input("Enter Year : "))
            print(f"date of birth is : {date}/{month}/{year}")
            contect_no=int(input("Enter number : "))
            print(contect_no)
            print('\n')
        else:
            a=True
            while a:
                password=getpass.getpass("Password is wrong enter password again : ")
                c_password=getpass.getpass("Confirm password : ")
                if password==c_password:
                    Gender=input("Enter gander name : ")
                    print(Gender)
                    print("Date of Birth")
                    date=int(input("Enter date : "))
                    month=int(input("Enter month :  "))
                    year=int(input("Enter year :   "))
                    print(f"Date of birth is : {date}/{month}/{year}")
                    contect_no=int(input("Enter phone number : "))
                    print(contect_no)
                    a=False
                    print(password)
                    print('\n')
 
        

    def course(self):
        print('--------------------')
        print("Course Information")
        print('--------------------')
        print("Enter courses")
        sub=[]
        name=input("Enter  5 subject name with comma seperated :").split(",")
        for i in name:
            sub.append(i)
        print(sub)
        if len(sub)==5:
            print("Thanks for registration")
        else:
            print(f"Total subject is :{len(sub)} please enter 5 subject")
            sub.clear()
            sub=[]
            a=True
            while a:
                name=input("Enter  5 subject name with comma seperated :").split(",")
                if (len(name)==5) or (len(name)>5):
                    sub.append(name)
                    a=False
                    for i in sub:
                        print("Your Entered Subject is", i)
        print('\n')
# ----------------------------------------------------------------------------------------------                        
    def teacher_info(self):
        print('--------------------')
        print("Teacher Information")
        print('--------------------')
        teacher={
            "sir qamar :" : "He is senior english teacher he has done MA englisg \n",
             "sir hammad :" : "He is urdu teacher he has done MA urdu \n",
             "sir kamraan :" : "He is senior math teacher he has done bs(math) from punjab university \n",
             "sir faizanr :" : "He is senior biology teacher he has done bs in agriculture university \n",
             "sir ajmal : " : "He is sphysics teacher he has done bs ein physics \n",
             "sir rafeeq : " : "He is senior pak study  he has done MA in social science\n",
             "sir kashif : " : "he is senior chimistry teacher he has done msc chemistry \n",
             "sir nasir : " : "he is senior computer teacher he has done bs(cs) from fast university \n",       
            
        }
        for name,info in teacher.items():
            print(name,info)
            
        print('\n')
# ------------------------------------------------------------------------------------------------------
    
    
    def fee_submition(self):
        print('--------------------')
        print("Fee Information")
        print('--------------------')
        print("Show fee submition details")
        student=["ahsan","ali","hamza","sadiq","tufail","saad"]
        defaulter=["ajmal","bilal","talha","usama","riaz","javi"]
        name=input("Please enter the name : ")
        if name in student:
            print("Your fee has been submitted")
        elif name in defaulter:
            print("You are a defaulter please submit your fee")
        else:
            print("You are not inrolled please inrolled")
            Name=input("Enter your name : ")
            f_Name=input("Enter your father name : ")
            Confrom=("have you submit the fee?")
            
            if Confrom == "yes":
                student.append(Name)
                print("Thanks You ! \nYour fee has been submitted")
            else:
                defaulter.append(Name)
                print("You are a defaulter please submit your fee")
        print('\n')
                
# -------------------------------------------------------------------------------------------------------------                
            
            
            
            
SchoolName =input('Enter Your a School Name : ')
SchoolAdress=input("Enter an address of the school : ")
SM=SMS(SchoolName,SchoolAdress)
SM.info()
# Out:
# Enter Your a School Name : ali
# Enter an address of the school : karachi
# |-------------------------------------|
# WELCOME TO SCHOOL MANAGEMENT SYSTEM
# |-------------------------------------|
# ---------------------------
# Registerd You On Our School
# ---------------------------
# Enter your details
# Enter your first name : ahsan
# Enter your last name : ali
# Set Your Password : ········
# Confirm password : ········
# Enter gender name : male
# male
# Date of Birth :
# Enter date : 12
# Enter Month : 12
# Enter Year : 234
# date of birth is : 12/12/234
# Enter number : 1234
# 1234
#
#
# --------------------
# Teacher Information
# --------------------
# |-------------------------------------------------------------------------|
# 		- The Owner of the school is Ahsan Iftikhar
#
# 		- Bscs from Islamabad University
# |-------------------------------------------------------------------------|
# ...
# List of Teacher
# ...
# Qammar is the teacher of  : english
# ...

# %%
""
